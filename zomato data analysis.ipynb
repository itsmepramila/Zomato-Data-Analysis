# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv("Zomato data .csv")

# %%
df
# Out:
#                       name online_order book_table   rate  votes
# 0                    Jalsa          Yes        Yes  4.1/5    775  \
# 1           Spice Elephant          Yes         No  4.1/5    787
# 2          San Churro Cafe          Yes         No  3.8/5    918
# 3    Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4            Grand Village           No         No  3.8/5    166
# ..                     ...          ...        ...    ...    ...
# 143       Melting Melodies           No         No  3.3/5      0
# 144        New Indraprasta           No         No  3.3/5      0
# 145           Anna Kuteera          Yes         No  4.0/5    771
# 146                 Darbar           No         No  3.0/5     98
# 147          Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...

# %%
df.shape
# Out:
# (148, 7)

# %%
df.isnull().sum()
# Out:
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# approx_cost(for two people)    0
# listed_in(type)                0
# dtype: int64

# %% [markdown]
# # convert the data type of column

# %%
def handelRate(value):
    value = str(value).split('/')
    value = value[0]
    return float(value)

df['rate'] = df['rate'].apply(handelRate)
print(df.head())
# Out:
#                     name online_order book_table  rate  votes
# 0                  Jalsa          Yes        Yes   4.1    775  \
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    float64
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 8.2+ KB

# %% [markdown]
# # Type of restaurent

# %%
sns.countplot(x=df['listed_in(type)'])
plt.xlabel("Type of restaurant")
# Out:
# Text(0.5, 0, 'Type of restaurant')

# %%
import matplotlib.pyplot as plt

grouped_data = df.groupby('listed_in(type)')['votes'].sum()
result = grouped_data.reset_index()

# Plotting the data
plt.plot(result['listed_in(type)'], result['votes'], c="green", marker="o")
plt.xlabel("Type of restaurant")
plt.ylabel("Votes")
plt.title("Votes by Type of Restaurant")
plt.xticks(rotation=45)  # Rotate x-axis labels if needed for better readability
plt.tight_layout()  # Adjust layout to prevent overlapping
plt.show()

# %%
# dinning restaurents has recieved maximum votes

# %%
plt.hist(df['rate'], bins=4)
plt.title("ratings disrtribution")
plt.show()

# %%
# the majority restaurents ratings from 3.5 to 4

# %%
# Extracting the column correctly
couple_data = df['approx_cost(for two people)']  # Ensure the column name matches exactly

# Plotting the count plot
sns.countplot(x=couple_data)  # Use x= or y= to specify the axis
plt.show()  # Always include this to display the plot

# %%
# the majority of the couples prefer restaurents with an appopriate cost of 300 rupees
